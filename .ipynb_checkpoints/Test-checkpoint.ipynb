# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
#Importing Data
data = pd.read_csv("data/ACLED2021-2024.csv")
data
# Out:
#       event_id_cnty     event_date  year  time_precision  \
# 0          ISR39789  19 April 2024  2024               1
# 1          ISR39807  19 April 2024  2024               1
# 2          ISR39813  19 April 2024  2024               1
# 3          ISR39815  19 April 2024  2024               1
# 4          ISR39842  19 April 2024  2024               1
# ...             ...            ...   ...             ...
# 38125      PSE19823  20 April 2021  2021               1
# 38126      PSE19822  20 April 2021  2021               1
# 38127       PSE8831  20 April 2021  2021               1
# 38128      PSE19816  20 April 2021  2021               1
# 38129       PSE8845  20 April 2021  2021               1
#
#                 disorder_type                  event_type  \
# 0          Political violence  Explosions/Remote violence
# 1              Demonstrations                    Protests
# 2              Demonstrations                       Riots
# 3              Demonstrations                    Protests
# 4          Political violence                     Battles
# ...                       ...                         ...
# 38125  Strategic developments      Strategic developments
# 38126      Political violence                       Riots
# 38127          Demonstrations                    Protests
# 38128      Political violence                       Riots
# 38129  Strategic developments      Strategic developments
#
#                           sub_event_type  \
# 0      Shelling/artillery/missile attack
# 1                       Peaceful protest
# 2                  Violent demonstration
# 3                       Peaceful protest
# 4                            Armed clash
# ...                                  ...
# 38125                              Other
# 38126                       Mob violence
# 38127                   Peaceful protest
# 38128                       Mob violence
# 38129       Looting/property destruction
#
#                                       actor1  \
# 0                             Hamas Movement
# 1                        Protesters (Israel)
# 2                           Rioters (Israel)
# 3                        Protesters (Israel)
# 4                                  Hezbollah
# ...                                      ...
# 38125  Military Forces of Israel (2009-2021)
# 38126                       Rioters (Israel)
# 38127                 Protesters (Palestine)
# 38128                       Rioters (Israel)
# 38129                         Hamas Movement
#
#                                            assoc_actor_1  inter1  ...  \
# 0                                                    NaN       3  ...
# 1                                                    NaN       6  ...
# 2                                                    NaN       5  ...
# 3                                                    NaN       6  ...
# 4                                                    NaN       3  ...
# ...                                                  ...     ...  ...
# 38125                                                NaN       8  ...
# 38126                                  Settlers (Israel)       5  ...
# 38127  DFLP: Democratic Front for the Liberation of P...       6  ...
# 38128                                  Settlers (Israel)       5  ...
# 38129                                                NaN       3  ...
#
#       latitude longitude  geo_precision  \
# 0      31.5250   34.5969              2
# 1      32.6363   34.9324              2
# 2      31.8766   34.9205              2
# 3      31.9710   34.7894              2
# 4      33.1288   35.5523              2
# ...        ...       ...            ...
# 38125  31.5839   34.4659              2
# 38126  31.5159   35.1639              1
# 38127  31.4178   34.3503              1
# 38128  31.9333   35.2167              2
# 38129  31.4988   34.4699              1
#
#                                                   source  \
# 0                                   N12; Times of Israel
# 1                                                   Ynet
# 2      Haaretz; Jerusalem Post; N12; Times of Israel;...
# 3                                                   Ynet
# 4               Jerusalem Post; Ma'ariv; Times of Israel
# ...                                                  ...
# 38125                PLO Negotiations Affairs Department
# 38126                PLO Negotiations Affairs Department
# 38127                                  Ma'an News Agency
# 38128                PLO Negotiations Affairs Department
# 38129                 Dunia Al Watan; Liveuamap; Twitter
#
#                   source_scale  \
# 0                     National
# 1                     National
# 2                     National
# 3                     National
# 4                     National
# ...                        ...
# 38125                    Other
# 38126                    Other
# 38127                 National
# 38128                    Other
# 38129  Local partner-New media
#
#                                                    notes fatalities  \
# 0      Interception: On 19 April 2024, Hamas militant...          0
# 1      On 19 April 2024, thousands formed a human cha...          0
# 2      On 19 April 2024, dozens of relatives of hosta...          0
# 3      On 19 April 2024, thousands formed a human cha...          0
# 4      On 19 April 2024, Hezbollah forces in Lebanon ...          0
# ...                                                  ...        ...
# 38125  Other: On 20 April 2021, Israeli military forc...          0
# 38126  On 20 April 2021, Israeli settlers uprooted 20...          0
# 38127  On 20 April 2021, a large protest organized by...          0
# 38128  On 20 April 2021, Israeli settlers from the Ba...          0
# 38129  Interceptions: On 20 April 2021, Palestinian r...          0
#
#                        tags   timestamp population_best
# 0                       NaN  1713830556         16571.0
# 1      crowd size=thousands  1713830556           232.0
# 2         crowd size=dozens  1713830556          1636.0
# 3      crowd size=thousands  1713830556         26118.0
# 4                       NaN  1713830556           997.0
# ...                     ...         ...             ...
# 38125                   NaN  1673314244             NaN
# 38126  crowd size=no report  1680570805          9630.0
# 38127      crowd size=large  1698715404         33386.0
# 38128  crowd size=no report  1709590337         20460.0
# 38129                   NaN  1709590397             NaN
#
# [38130 rows x 32 columns]

# %%
#Dropping Columns
data.drop(columns=['time_precision', 'assoc_actor_1', 'assoc_actor_2', 'iso', 'region', 'admin3', 'location', 
                  'latitude', 'longitude', 'geo_precision', 'source_scale', 'timestamp', 'tags', 'population_best', 'event_id_cnty'], 
          inplace=True)

#Reformatting / Cleaning
data['event_date'] = pd.to_datetime(data['event_date'], errors = 'coerce')
#data['admin2'].fillna(data['admin1'], inplace = True)
data.loc[:, 'actor2'] = data['actor2'].fillna('Not specified')
data.loc[:, 'civilian_targeting'] = data['civilian_targeting'].fillna('Not specified')

# %%
# Dropping Dupes
initial_row_count = data.shape[0]
data = data.drop_duplicates()
final_row_count = data.shape[0]
print(f"Removed {initial_row_count - final_row_count} duplicates")
data
# Out:
# Removed 40 duplicates
#       event_date  year           disorder_type                  event_type  \
# 0     2024-04-19  2024      Political violence  Explosions/Remote violence
# 1     2024-04-19  2024          Demonstrations                    Protests
# 2     2024-04-19  2024          Demonstrations                       Riots
# 3     2024-04-19  2024          Demonstrations                    Protests
# 4     2024-04-19  2024      Political violence                     Battles
# ...          ...   ...                     ...                         ...
# 38125 2021-04-20  2021  Strategic developments      Strategic developments
# 38126 2021-04-20  2021      Political violence                       Riots
# 38127 2021-04-20  2021          Demonstrations                    Protests
# 38128 2021-04-20  2021      Political violence                       Riots
# 38129 2021-04-20  2021  Strategic developments      Strategic developments
#
#                           sub_event_type  \
# 0      Shelling/artillery/missile attack
# 1                       Peaceful protest
# 2                  Violent demonstration
# 3                       Peaceful protest
# 4                            Armed clash
# ...                                  ...
# 38125                              Other
# 38126                       Mob violence
# 38127                   Peaceful protest
# 38128                       Mob violence
# 38129       Looting/property destruction
#
#                                       actor1  inter1  \
# 0                             Hamas Movement       3
# 1                        Protesters (Israel)       6
# 2                           Rioters (Israel)       5
# 3                        Protesters (Israel)       6
# 4                                  Hezbollah       3
# ...                                      ...     ...
# 38125  Military Forces of Israel (2009-2021)       8
# 38126                       Rioters (Israel)       5
# 38127                 Protesters (Palestine)       6
# 38128                       Rioters (Israel)       5
# 38129                         Hamas Movement       3
#
#                                       actor2  inter2  interaction  \
# 0                              Not specified       0           30
# 1                              Not specified       0           60
# 2                           Rioters (Israel)       5           55
# 3                              Not specified       0           60
# 4          Military Forces of Israel (2022-)       1           13
# ...                                      ...     ...          ...
# 38125                  Civilians (Palestine)       7           78
# 38126                          Not specified       0           50
# 38127                          Not specified       0           60
# 38128                  Civilians (Palestine)       7           57
# 38129  Military Forces of Israel (2009-2021)       8           38
#
#        civilian_targeting    country      admin1                 admin2  \
# 0           Not specified     Israel     HaDarom               Ashqelon
# 1           Not specified     Israel       Haifa                 Hadera
# 2           Not specified     Israel    HaMerkaz                  Ramla
# 3           Not specified     Israel    HaMerkaz                Rehovot
# 4           Not specified     Israel     HaZafon                  Zefat
# ...                   ...        ...         ...                    ...
# 38125       Not specified  Palestine  Gaza Strip             North Gaza
# 38126       Not specified  Palestine   West Bank                 Hebron
# 38127       Not specified  Palestine  Gaza Strip          Deir El Balah
# 38128  Civilian targeting  Palestine   West Bank  Ramallah and Al Bireh
# 38129       Not specified  Palestine  Gaza Strip              Gaza City
#
#                                                   source  \
# 0                                   N12; Times of Israel
# 1                                                   Ynet
# 2      Haaretz; Jerusalem Post; N12; Times of Israel;...
# 3                                                   Ynet
# 4               Jerusalem Post; Ma'ariv; Times of Israel
# ...                                                  ...
# 38125                PLO Negotiations Affairs Department
# 38126                PLO Negotiations Affairs Department
# 38127                                  Ma'an News Agency
# 38128                PLO Negotiations Affairs Department
# 38129                 Dunia Al Watan; Liveuamap; Twitter
#
#                                                    notes  fatalities
# 0      Interception: On 19 April 2024, Hamas militant...           0
# 1      On 19 April 2024, thousands formed a human cha...           0
# 2      On 19 April 2024, dozens of relatives of hosta...           0
# 3      On 19 April 2024, thousands formed a human cha...           0
# 4      On 19 April 2024, Hezbollah forces in Lebanon ...           0
# ...                                                  ...         ...
# 38125  Other: On 20 April 2021, Israeli military forc...           0
# 38126  On 20 April 2021, Israeli settlers uprooted 20...           0
# 38127  On 20 April 2021, a large protest organized by...           0
# 38128  On 20 April 2021, Israeli settlers from the Ba...           0
# 38129  Interceptions: On 20 April 2021, Palestinian r...           0
#
# [38090 rows x 17 columns]
